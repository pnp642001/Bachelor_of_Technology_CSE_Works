# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# %cd MyDrive/Colab\ Notebooks
# %ls
# Out:
# /gdrive/MyDrive/Colab Notebooks
# 'Computer Vision Notebooks'/         'Practical 9.ipynb'
# 'Linear Regression.ipynb'            'Practicals-6CSE 21-22.ipynb'
# 'Logistic Regression.ipynb'          'Practicals ML 6IT 2021-22.ipynb'
# 'ML Practical 6.ipynb'               'Temporary Colab File.ipynb'
# 'ML Practical 7 - Clustering.ipynb'  'Text Summarizer.ipynb'

# %%
# %cd
# Out:
# /root

# %%
# %cd /gdrive/MyDrive/Datasets
# %ls
# Out:
# /gdrive/MyDrive/Datasets
#  breast_cancer_data.csv              finalized_sklearn_classification_model.sav
# 'Concrete Regression Dataset.csv'   'garments_worker_productivity dataset.csv'
#  credit_card_clients.xls            'glass classification dataset.csv'
# 'Credit Card Customer Dataset.csv'   Mall_Customers_dataset.csv
#  cwurData.csv                        ppb_chart.png
# 'drug classification dataset.csv'    WineQT.csv
#  fifa19_dataset.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('WineQT.csv')
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  alcohol  quality  Id
# 0            7.4              0.70         0.00  ...      9.4        5   0
# 1            7.8              0.88         0.00  ...      9.8        5   1
# 2            7.8              0.76         0.04  ...      9.8        5   2
# 3           11.2              0.28         0.56  ...      9.8        6   3
# 4            7.4              0.70         0.00  ...      9.4        5   4
#
# [5 rows x 13 columns]

# %%
df.drop('Id', axis=1, inplace=True)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
from sklearn.neural_network import MLPClassifier

# %%
y = df['quality']

# %%
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
X = df.drop('quality', axis=1, inplace=False)
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...    pH  sulphates  alcohol
# 0            7.4              0.70         0.00  ...  3.51       0.56      9.4
# 1            7.8              0.88         0.00  ...  3.20       0.68      9.8
# 2            7.8              0.76         0.04  ...  3.26       0.65      9.8
# 3           11.2              0.28         0.56  ...  3.16       0.58      9.8
# 4            7.4              0.70         0.00  ...  3.51       0.56      9.4
#
# [5 rows x 11 columns]

# %%
X.describe()
# Out:
#        fixed acidity  volatile acidity  ...    sulphates      alcohol
# count    1143.000000       1143.000000  ...  1143.000000  1143.000000
# mean        8.311111          0.531339  ...     0.657708    10.442111
# std         1.747595          0.179633  ...     0.170399     1.082196
# min         4.600000          0.120000  ...     0.330000     8.400000
# 25%         7.100000          0.392500  ...     0.550000     9.500000
# 50%         7.900000          0.520000  ...     0.620000    10.200000
# 75%         9.100000          0.640000  ...     0.730000    11.100000
# max        15.900000          1.580000  ...     2.000000    14.900000
#
# [8 rows x 11 columns]

# %%
model = MLPClassifier(solver='sgd', hidden_layer_sizes=(16, 8), random_state=1, learning_rate_init=0.005, learning_rate='adaptive', verbose=True, validation_fraction=0.1, early_stopping=True)

# %%
model.fit(X,y)
# Out:
# Iteration 1, loss = 8.01325394
# Validation score: 0.443478
# Iteration 2, loss = 1.47647318
# Validation score: 0.443478
# Iteration 3, loss = 1.25666158
# Validation score: 0.443478
# Iteration 4, loss = 1.23515458
# Validation score: 0.443478
# Iteration 5, loss = 1.23053153
# Validation score: 0.547826
# Iteration 6, loss = 1.20320713
# Validation score: 0.556522
# Iteration 7, loss = 1.18583204
# Validation score: 0.582609
# Iteration 8, loss = 1.18022303
# Validation score: 0.565217
# Iteration 9, loss = 1.17713216
# Validation score: 0.565217
# Iteration 10, loss = 1.17021029
# Validation score: 0.556522
# Iteration 11, loss = 1.16551101
# Validation score: 0.573913
# Iteration 12, loss = 1.16545077
# Validation score: 0.582609
# Iteration 13, loss = 1.15980360
# Validation score: 0.513043
# Iteration 14, loss = 1.16516763
# Validation score: 0.573913
# Iteration 15, loss = 1.16483763
# Validation score: 0.547826
# Iteration 16, loss = 1.18017384
# Validation score: 0.582609
# ...

# %%
model2 = MLPClassifier(solver='sgd', hidden_layer_sizes=(24, 8), random_state=1, learning_rate_init=0.005, learning_rate='adaptive', verbose=True, validation_fraction=0.1, early_stopping=True)
model2.fit(X,y)
# Out:
# Iteration 1, loss = 3.20808537
# Validation score: 0.434783
# Iteration 2, loss = 1.33572237
# Validation score: 0.443478
# Iteration 3, loss = 1.24416561
# Validation score: 0.460870
# Iteration 4, loss = 1.19113087
# Validation score: 0.400000
# Iteration 5, loss = 1.20443332
# Validation score: 0.469565
# Iteration 6, loss = 1.16941668
# Validation score: 0.452174
# Iteration 7, loss = 1.16628409
# Validation score: 0.434783
# Iteration 8, loss = 1.16111996
# Validation score: 0.426087
# Iteration 9, loss = 1.15956707
# Validation score: 0.417391
# Iteration 10, loss = 1.15269689
# Validation score: 0.426087
# Iteration 11, loss = 1.15229258
# Validation score: 0.443478
# Iteration 12, loss = 1.13932787
# Validation score: 0.460870
# Iteration 13, loss = 1.14025064
# Validation score: 0.478261
# Iteration 14, loss = 1.13859309
# Validation score: 0.408696
# Iteration 15, loss = 1.16449212
# Validation score: 0.460870
# Iteration 16, loss = 1.13583996
# Validation score: 0.469565
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(model.loss_curve_)

# %%
plt.plot(model2.loss_curve_)

# %%
model3 = MLPClassifier(solver='sgd', hidden_layer_sizes=(16, 12), random_state=1, learning_rate_init=0.001, learning_rate='invscaling', verbose=True, validation_fraction=0.1, early_stopping=True)
model3.fit(X,y)
# Out:
# Iteration 1, loss = 11.06315188
# Validation score: 0.452174
# Iteration 2, loss = 3.61112328
# Validation score: 0.452174
# Iteration 3, loss = 3.55871153
# Validation score: 0.452174
# Iteration 4, loss = 2.71928891
# Validation score: 0.469565
# Iteration 5, loss = 2.70146343
# Validation score: 0.478261
# Iteration 6, loss = 2.77401929
# Validation score: 0.478261
# Iteration 7, loss = 2.70547732
# Validation score: 0.469565
# Iteration 8, loss = 2.59102506
# Validation score: 0.478261
# Iteration 9, loss = 2.49181436
# Validation score: 0.530435
# Iteration 10, loss = 2.43275829
# Validation score: 0.530435
# Iteration 11, loss = 2.39087727
# Validation score: 0.539130
# Iteration 12, loss = 2.35369202
# Validation score: 0.539130
# Iteration 13, loss = 2.31961518
# Validation score: 0.539130
# Iteration 14, loss = 2.28735259
# Validation score: 0.539130
# Iteration 15, loss = 2.25647562
# Validation score: 0.530435
# Iteration 16, loss = 2.22885796
# Validation score: 0.530435
# ...

# %%
plt.plot(model3.loss_curve_)

# %%
model3.score(X,y)
# Out:
# 0.5048118985126859

# %%
import pickle

# %%
filename = 'finalized_sklearn_classification_model.sav'
pickle.dump(model3, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
loaded_model.score(X,y)
# Out:
# 0.5048118985126859
